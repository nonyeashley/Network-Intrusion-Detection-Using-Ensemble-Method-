# %% [markdown]
# <a href="https://colab.research.google.com/github/nonyeashley/Network-Intrusion-Detection-Using-Ensemble-Method-/blob/main/UCI_Network_Intrusion_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## pandas, numpy, matplotlib, seaborn
import pandas as pd ## load the categorical data
import numpy as np ## it is used when working with array
import matplotlib.pyplot as plt ## plotting
import seaborn as sns ## for advanced plotting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## declaring the variable
train_file_path = '/content/drive/MyDrive/RT_IOT2022.csv'
## variable name holding my dataset ("train_file_path")
df = pd.read_csv(train_file_path)
## variabe name "df" allows me to read my dataset

# %%
df.head(5) ## checking the first 5 columns of the dataset
# Out:
#    Unnamed: 0  id.orig_p  id.resp_p proto service  flow_duration  \
# 0           0      38667       1883   tcp    mqtt      32.011598
# 1           1      51143       1883   tcp    mqtt      31.883584
# 2           2      44761       1883   tcp    mqtt      32.124053
# 3           3      60893       1883   tcp    mqtt      31.961063
# 4           4      51087       1883   tcp    mqtt      31.902362
#
#    fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# 0             9             5                  3                  3  ...
# 1             9             5                  3                  3  ...
# 2             9             5                  3                  3  ...
# 3             9             5                  3                  3  ...
# 4             9             5                  3                  3  ...
#
#    active.std      idle.min      idle.max      idle.tot      idle.avg  \
# ...

# %%
df.tail(5) ## checking the last 5 columns of the dataset
# Out:
#         Unnamed: 0  id.orig_p  id.resp_p proto service  flow_duration  \
# 123112        2005      59247      63331   tcp       -       0.000006
# 123113        2006      59247      64623   tcp       -       0.000007
# 123114        2007      59247      64680   tcp       -       0.000006
# 123115        2008      59247      65000   tcp       -       0.000006
# 123116        2009      59247      65129   tcp       -       0.000006
#
#         fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# 123112             1             1                  0                  0  ...
# 123113             1             1                  0                  0  ...
# 123114             1             1                  0                  0  ...
# 123115             1             1                  0                  0  ...
# 123116             1             1                  0                  0  ...
#
#         active.std  idle.min  idle.max  idle.tot  idle.avg  idle.std  \
# ...

# %%
df.isnull().sum() ## checking for missing values
# Out:
# Unnamed: 0              0
# id.orig_p               0
# id.resp_p               0
# proto                   0
# service                 0
#                        ..
# idle.std                0
# fwd_init_window_size    0
# bwd_init_window_size    0
# fwd_last_window_size    0
# Attack_type             0
# Length: 85, dtype: int64

# %%
df.info () ## checking for datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123117 entries, 0 to 123116
# Data columns (total 85 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                123117 non-null  int64
#  1   id.orig_p                 123117 non-null  int64
#  2   id.resp_p                 123117 non-null  int64
#  3   proto                     123117 non-null  object
#  4   service                   123117 non-null  object
#  5   flow_duration             123117 non-null  float64
#  6   fwd_pkts_tot              123117 non-null  int64
#  7   bwd_pkts_tot              123117 non-null  int64
#  8   fwd_data_pkts_tot         123117 non-null  int64
#  9   bwd_data_pkts_tot         123117 non-null  int64
#  10  fwd_pkts_per_sec          123117 non-null  float64
#  11  bwd_pkts_per_sec          123117 non-null  float64
#  12  flow_pkts_per_sec         123117 non-null  float64
# ...
